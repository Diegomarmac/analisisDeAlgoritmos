# %% [markdown]
# # Adivina el número

# %% [markdown]
# ![problema0-1.jpg](attachment:problema0-1.jpg)

# %% [markdown]
# ![problema0-2.jpg](attachment:problema0-2.jpg)

# %% [markdown]
# ![problema0-3-2.jpg](attachment:problema0-3-2.jpg)

# %% [markdown]
# ## Prueba
# es importante que el arreglo usado como _base_esté ordenado, el algoritmo __no__ contempla el revisar si está o no ordenado.
#
# Al ser un algoritmo recursivo algo importante es probar que el algoritmo termina, para esto tenemos 2 casos:
# - El usuario indica que ya se ha encontrado el número deseado, entonces el programa termina
# - El usuario _hace trampa_, en este caso el programa repetirá el número a donde se le ha _acorralado_, ya que el profesor indico que no hubiera un momento de limite de intentos para terminar el programa, en este caso, el usuario deberá indicar que se ha encontrado el número y el programa terminará. En este punto, al quedar _acorralado_ en un solo número, es el fin del del ciclo, es decir se mantendrá ahí mientras el usuario así lo desee, el loop no se moverá. por lo que queda notorio que los limites no incrementan infinitamente.
#
# ¿ Cúantas Veces se hará el loop ?
# - Mejor caso: 1, en este caso el arreglo es de tamaño 0 o 1, de modo que no puede realizar la operación $LI + (\frac{LS-LI}{2})$ o donde al primer intento se encuentra el número deseado.
# - Caso Promedio: Aquí no importa de que lado queda el número a buscar, lo que nos interesa es que exista una iteración siguiente donde los subarreglos sean menores que los anteriores
#
# Dentro de la longitud del ArregloOrdenado nuestro algoritmo se ejecutará de forma recursiva, primero se toma la mitad de la longitud del arreglo, llamemos a este número n, y se pregunta si es el número a buscar, de forma que si es, hemos encontrado el mejor caso, de otra manera tenemos 2 posibles casos que el número a buscar sea menor o sea mayor de la mitad del arreglo.
# Si el número a buscar es menor que el dado, entonces como ArregloOrdenado está ordenado, podemos seguir _partiendo a mitades_ , para este caso, actualizamos el límite superior de busqueda como el primer número dado, es decir, el límite superior es ahora n, y volvemos a ejecutar el algoritmo pero teniendo ahora como limite superior n. En este punto es notorio que se regresa al caso base, con los valores actualziados.
# Si el número a buscar es mayo, entonces tomamos n como el nuevo limite inferior, y ahora va desde n hasta el extremo superior, este será nuestro nuevo arreglo para buscar, en este punto volvemos a realziar la busqueda de forma recursiva, con lo que regresaremos al caso base.

# %% [markdown]
# ## El codigo

# %%
function guessTheNumber(limiteSuperior, limiteInferior)
    variableABuscar = limiteInferior + ((limiteSuperior - limiteInferior)/2) #El principio de BInary Search se basa en irnos a mitades hacia arriba o hacia abajo, usamos ese principio
    variableABuscar = trunc(Int,variableABuscar) # Con esto convertimos el resultado a Entero
    println("El número a buscar es: ", variableABuscar, "?")
    println("Presione 'g' si el número a buscar es más grande")
    println("Presione 'b' si el número a buscar es más bajo")
    println("Presione 'c' si el número a buscar es el correcto")
    respuesta = chomp(readline())
    while respuesta ∉ ["c", "b", "g"] #Que el usuario SOLAMENTE pueda ingresar las opciones que queremos
        print("Por favor seleccione solamente \"c\", \"b\", o \"g\". ")
        respuesta = chomp(readline())
    end
    if respuesta == "c" # Esto es solamente gestión de entrada, si ya se encontró el número, pos GAME OVER
        println("Genial ya encontramos el número!")
    elseif respuesta == "b"
        limiteSuperior = variableABuscar
        guessTheNumber(limiteSuperior, limiteInferior) # Si el númeroa buscar es menor, entonces tomamos el número dado como el limite superior para la siguiente busqueda
    else
        limiteInferior = variableABuscar
        guessTheNumber(limiteSuperior,limiteInferior) # Si el númeroa buscar es mayor, entonces tomamos el número dado como el limite inferior para la siguiente busqueda
    end
end
# Out:
# guessTheNumber (generic function with 1 method)

# %%
# Solo descomente la dificultad deseada y comente las que NO se vayan a ocupar
# la gestión de inputs del usuario se hace en el codigo binarySearch.jl que se encuentra en el repo

#dificultad Rapida
arreglo = collect(1:10)
#Dificultad Media
# arreglo = collect(1:100)
#Dificultad Tediosa
# arreglo = collect(1:1000)

println("Piensa en un número entre 1 y",length(arreglo),"... listo ? comencemos !")
guessTheNumber(length(arreglo),0)
